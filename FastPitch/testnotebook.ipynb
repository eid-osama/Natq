# %%
# %pip install gdown
# Out:
# ...
#   Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# ...
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# ...
#   Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl (105 kB)
# ...
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# ...
#   Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\eid\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import gdown

# %%
file_id = "18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht"
url = f"https://drive.google.com/uc?id={file_id}"

# This will show a progress bar in the notebook output
gdown.download(url, 'HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht
# From (redirected): https://drive.google.com/uc?id=18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht&confirm=t&uuid=28a98d1c-41c7-4c2e-b2cd-15d2dfbc04cf
# To: e:\Natq\FastPitch\HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
# 100%|██████████| 946M/946M [05:09<00:00, 3.05MB/s]
# 'HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip'

# %%
# !unzip HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
# Out:
# Archive:  HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
#   inflating: HifiGan--val_loss=0.3817-epoch=34-last.ckpt

# %%
# !gdown 1G0vVsuxdNeV02dHTvl1VxT4Bw2hVsmYe
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1G0vVsuxdNeV02dHTvl1VxT4Bw2hVsmYe
# From (redirected): https://drive.google.com/uc?id=1G0vVsuxdNeV02dHTvl1VxT4Bw2hVsmYe&confirm=t&uuid=24221b93-525b-4bee-ac4a-c47767bb2631
# To: e:\Natq\FastPitch\FastPitch--val_loss=0.7130-epoch=49-last.ckpt.zip
#
#   0%|          | 0.00/500M [00:00<?, ?B/s]
#   0%|          | 524k/500M [00:00<04:48, 1.73MB/s]
#   0%|          | 1.05M/500M [00:00<04:31, 1.84MB/s]
#   0%|          | 1.57M/500M [00:00<03:14, 2.56MB/s]
#   0%|          | 2.10M/500M [00:00<02:53, 2.86MB/s]
#   1%|          | 2.62M/500M [00:00<02:40, 3.09MB/s]
#   1%|          | 3.15M/500M [00:01<02:37, 3.16MB/s]
#   1%|          | 3.67M/500M [00:01<02:32, 3.26MB/s]
#   1%|          | 4.19M/500M [00:01<02:26, 3.38MB/s]
#   1%|          | 4.72M/500M [00:01<02:25, 3.42MB/s]
#   1%|          | 5.24M/500M [00:01<02:21, 3.50MB/s]
#   1%|          | 5.77M/500M [00:01<02:20, 3.51MB/s]
# ...

# %%
# !unzip FastPitch--val_loss=0.7130-epoch=49-last.ckpt.zip
# Out:
# Archive:  FastPitch--val_loss=0.7130-epoch=49-last.ckpt.zip
#   inflating: FastPitch--val_loss=0.7130-epoch=49-last.ckpt

# %%
hfg_path_gt = "HifiGan--val_loss=0.3817-epoch=34-last.ckpt"
vocoder_model = HifiGanModel.load_from_checkpoint(checkpoint_path=hfg_path_gt).eval().cuda()
