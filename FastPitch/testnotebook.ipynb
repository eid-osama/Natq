# %%
import gdown

# %%
file_id = "18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht"
url = f"https://drive.google.com/uc?id={file_id}"

# This will show a progress bar in the notebook output
gdown.download(url, 'HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht
# From (redirected): https://drive.google.com/uc?id=18MMnP1VSXuxu55TFFBA4JKm5Tv28Lfht&confirm=t&uuid=28a98d1c-41c7-4c2e-b2cd-15d2dfbc04cf
# To: e:\Natq\FastPitch\HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
# 100%|██████████| 946M/946M [05:09<00:00, 3.05MB/s]
# 'HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip'

# %%
# !unzip HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
# Out:
# Archive:  HifiGan--val_loss=0.3817-epoch=34-last.ckpt.zip
#   inflating: HifiGan--val_loss=0.3817-epoch=34-last.ckpt

# %%
# !gdown 1h8X7__PK3oNNVB6RUlvPxJKlDnwJYsOV
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1h8X7__PK3oNNVB6RUlvPxJKlDnwJYsOV
# From (redirected): https://drive.google.com/uc?id=1h8X7__PK3oNNVB6RUlvPxJKlDnwJYsOV&confirm=t&uuid=9813d666-06c8-4790-866f-423d1a5d9cf4
# To: e:\Natq\FastPitch\FastPitch--val_loss=0.5327-epoch=79-last.ckpt.zip
#
#   0%|          | 0.00/500M [00:00<?, ?B/s]
#   0%|          | 524k/500M [00:00<14:58, 556kB/s]
#   0%|          | 1.05M/500M [00:01<08:23, 992kB/s]
#   0%|          | 1.57M/500M [00:01<05:41, 1.46MB/s]
#   0%|          | 2.10M/500M [00:01<07:23, 1.12MB/s]
#   1%|          | 3.15M/500M [00:02<04:59, 1.66MB/s]
#   1%|          | 3.67M/500M [00:02<04:26, 1.87MB/s]
#   1%|          | 4.19M/500M [00:02<04:10, 1.98MB/s]
#   1%|          | 4.72M/500M [00:02<03:56, 2.09MB/s]
#   1%|          | 5.24M/500M [00:03<03:54, 2.11MB/s]
#   1%|          | 5.77M/500M [00:03<03:49, 2.15MB/s]
#   1%|▏         | 6.29M/500M [00:03<03:41, 2.23MB/s]
# ...

# %%
# !unzip FastPitch--val_loss=0.5327-epoch=79-last.ckpt.zip
# Out:
# Archive:  FastPitch--val_loss=0.5327-epoch=79-last.ckpt.zip
#   inflating: FastPitch--val_loss=0.5327-epoch=79-last.ckpt
